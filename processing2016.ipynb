# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mov_metadata1 = pd.read_csv('./datasets/movie_metadata1.csv')

# %%
mov_metadata1.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
mov_metadata1.shape
# Out:
# (5043, 28)

# %% [markdown]
# # metadata1 have movies only upto 2016
# ### metadata2 have upto 2017

# %%
data['title_year'].value_counts(dropna=False).sort_index().plot(kind='barh',figsize=(16,16))
plt.show()

# %%
print(data['director_name'].isna().sum(),
      data['actor_1_name'].isna().sum(),
      data['actor_2_name'].isna().sum(),
      data['actor_3_name'].isna().sum(),
      data['genres'].isna().sum(),
      data['movie_title'].isna().sum(),
     )
# Out:
# 104 7 13 23 0 0

# %%
# Keeping essentital data's only
data = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
data.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6          Sam Raimi     J.K. Simmons       James Franco
# 7       Nathan Greno     Brad Garrett       Donna Murphy
# 8        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 9        David Yates     Alan Rickman   Daniel Radcliffe
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action|Adventure|Fantasy|Sci-Fi
# 1        Jack Davenport                           Action|Adventure|Fantasy
# 2      Stephanie Sigman                          Action|Adventure|Thriller
# ...

# %%
data['actor_1_name'] = data['actor_1_name'].replace(np.nan, 'not available')
data['actor_2_name'] = data['actor_2_name'].replace(np.nan, 'not available')
data['actor_3_name'] = data['actor_3_name'].replace(np.nan, 'not available')
data['director_name'] = data['director_name'].replace(np.nan, 'not available')

# %%
data
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039      not available      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport         Action|Adventure|Fantasy
# 2         Stephanie Sigman        Action|Adventure|Thriller
# ...

# %%
data['genres'] = data['genres'].str.split('|')

# %%
data.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6          Sam Raimi     J.K. Simmons       James Franco
# 7       Nathan Greno     Brad Garrett       Donna Murphy
# 8        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 9        David Yates     Alan Rickman   Daniel Radcliffe
#
#            actor_3_name                                             genres  \
# 0             Wes Studi               [Action, Adventure, Fantasy, Sci-Fi]
# 1        Jack Davenport                       [Action, Adventure, Fantasy]
# 2      Stephanie Sigman                      [Action, Adventure, Thriller]
# ...

# %%
data['movie_title'] = data['movie_title'].str.lower()

# %%
# null terminating char at the end
data['movie_title'][4]
# Out:
# 'star wars: episode vii - the force awakens\xa0            '

# %%
data['movie_title'].head(5)
# Out:
# 0                                              avatar
# 1            pirates of the caribbean: at world's end
# 2                                             spectre
# 3                               the dark knight rises
# 4    star wars: episode vii - the force awakens    ...
# Name: movie_title, dtype: object

# %%
data.to_csv('./datasets/processed2017.csv',index=False)
